# %%
import os
resultsPath = "../tmp/reports/"
dataset = 'magic'
results_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds.csv')

'''
with open(results_file,'r+') as results_f:
    lines = results_f.readlines()
    #results_f.write(lines[0])
    for line in lines:
        #if ('(' in line):
        if(not line.isspace()):
            results_f.write(line)

            
results_f.close()
'''

'''            
data_test = data_file +'.test'

file_write_train = open(data_train,'w')
file_write_test = open(data_test,'w')
file_read = open(data_all,'r')
lines = file_read.readlines()
for i in range(len(lines)):
    if (i %5 != 0):
        file_write_train.write(lines[i])
    else:
        file_write_test.write(lines[i])
        
        
    
    

file_write_train.close()
file_read.close()
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8864/2727311148.py in <module>
#       5
#       6
# ----> 7 with open(results_file,'rw') as results_f:
#       8     lines = results_f.readlines()
#       9     #results_f.write(lines[0])
#
# ValueError: must have exactly one of create/read/write/append mode

# %%
import os
import numpy as np
import math

resultsPath = "../tmp/final_reports/"
dataset = 'magic'
results_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds.csv')

sizes = [25,50,100]
depths = [5,10,15]
pattern_thresholds = [1,2]
edge_thresholds = [1.0,0.975,0.95,0.925,0.9,0.85,0.8,0.7,0.6]
accuracy_drop = 0.04
with open(results_file,'r') as f:
    lines = f.readlines()
f.close()  


stats_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds_'+str(accuracy_drop)+'.csv')
with open(stats_file,'w') as f_out:
    f_out.write('Forest Size, Forest Depth, Patterns Threshold, Edges Threshold, Test Accuracy, Accuracy drop, Patterns Count,Compression, Training Time, Pruning Time,\n')
    index = 0
    counter = 0
    line_index = []

    print('Forest Size, Forest Depth, Patterns Threshold, Edges Threshold, Test Accuracy, Accuracy drop, Patterns Count,Compression, Training Time, Pruning Time,')
    for i_s,s in enumerate(sizes):
        for i_d,d in enumerate(depths):
            for i_p,p in enumerate(pattern_thresholds):

                for i_e,e in enumerate(edge_thresholds):
                    line_arr = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                    
                    if (i_e == (len(edge_thresholds) - 1) and abs(float(line_arr[7])) <=  accuracy_drop):
                        index = len(edge_thresholds) - 1
                        line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                        print(edge_thresholds[index])
                        #line_arr = lines[line_index].split(',')
                        compression = np.round(1/float(line_index[14]),2)
                        print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                             str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                        f_out.write(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                             str(line_index[13])+','+str(compression)+','+str((line_index[15]))+','+str(line_index[16])+',\n')

                        counter += 1


                    else:
                        
                        if (abs(float(line_arr[7])) <=  accuracy_drop):
                            index = i_e
                            line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                            #print(line_index)
                        #if (i_e == (len(edge_thresholds) - 1)):
                        #   index = i_e
                        #    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                        #    print(edge_thresholds[index])
                        #    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                        #         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')

                        else:
                            print(edge_thresholds[index])
                            #line_arr = lines[line_index].split(',')
                            compression = np.round(1/float(line_index[14]),2)
                            print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                                 str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                            f_out.write(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                                 str(line_index[13])+','+str(compression)+','+str((line_index[15]))+','+str(line_index[16])+',\n')

                            counter += 1
                            break

'''               
compression = 1.5

index = 0
counter = 0
line_index = []


for i_s,s in enumerate(sizes):
    for i_d,d in enumerate(depths):
        for i_p,p in enumerate(pattern_thresholds):
            
            for i_e,e in enumerate(edge_thresholds):
                line_arr = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                
                if (abs(1/ float(line_arr[14])) >=  compression):
                    index = i_e
                    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                    #print(line_index)
                #if (i_e == (len(edge_thresholds) - 1)):
                #   index = i_e
                #    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                #    print(edge_thresholds[index])
                #    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                #         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                        
                else:
                    print(edge_thresholds[index])
                    #line_arr = lines[line_index].split(',')
                    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                    counter += 1
                    break
                    

'''
# Out:
# Forest Size, Forest Depth, Patterns Threshold, Edges Threshold, Test Accuracy, Accuracy drop, Patterns Count,Compression, Training Time, Pruning Time,
# 0.7
# 25,5,1,0.7,0.799,-0.03599999999999992,81,3.846153846153846,0:00:00.762783,0:00:02.505460
# ,
# 0.8
# 25,5,2,0.8,0.796,-0.03299999999999992,46,2.3041474654377883,0:00:00.320652,0:00:00.849382
# ,
# 0.6
# 25,10,1,0.6,0.793,-0.03499999999999992,108,10.638297872340425,0:00:01.349240,0:00:09.409364
# ,
# 0.6
# 25,10,2,0.6,0.795,-0.03399999999999992,104,7.751937984496124,0:00:01.278818,0:00:06.092150
# ,
# 0.6
# 25,15,1,0.6,0.793,-0.03599999999999992,109,12.048192771084336,0:00:01.365695,0:00:09.840998
# ,
# 0.6
# 25,15,2,0.6,0.793,-0.038999999999999924,109,9.708737864077671,0:00:01.367560,0:00:08.157951
# ,
# 0.7
# 50,5,1,0.7,0.801,-0.03699999999999992,118,4.166666666666667,0:00:01.189906,0:00:04.595672
# ,
# 0.7
# 50,5,2,0.7,0.798,-0.03799999999999992,62,3.3222591362126246,0:00:00.558022,0:00:01.601283
# ,
# 0.6
# 50,10,1,0.6,0.793,-0.03399999999999992,109,12.5,0:00:01.241060,0:00:09.943663
# ,
# 0.6
# 50,10,2,0.6,0.794,-0.03599999999999992,108,10.0,0:00:01.369990,0:00:08.215661
# ,
# 0.6
# 50,15,1,0.6,0.793,-0.03199999999999992,109,13.333333333333334,0:00:01.274296,0:00:10.360296
# ,
# 0.6
# 50,15,2,0.6,0.793,-0.03399999999999992,109,11.627906976744187,0:00:01.243658,0:00:09.633146
# ,
# 0.6
# 100,5,1,0.6,0.796,-0.03799999999999992,77,8.771929824561402,0:00:00.927504,0:00:04.726536
# ,
# 0.6
# 100,5,2,0.6,0.795,-0.039999999999999925,47,7.462686567164178,0:00:00.479602,0:00:02.625456
# ,
# 0.6
# 100,10,1,0.6,0.793,-0.03299999999999992,109,14.084507042253522,0:00:01.354385,0:00:10.799037
# ,
# 0.6
# 100,10,2,0.6,0.793,-0.03499999999999992,109,12.195121951219512,0:00:01.348038,0:00:10.496888
# ,
# 0.6
# 100,15,1,0.6,0.793,-0.03399999999999992,109,14.705882352941176,0:00:01.297836,0:00:11.212359
# ,
# 0.6
# 100,15,2,0.6,0.793,-0.03399999999999992,109,12.987012987012987,0:00:01.283657,0:00:10.049164
# ,
# "               \ncompression = 1.5\n\nindex = 0\ncounter = 0\nline_index = []\n\n\nfor i_s,s in enumerate(sizes):\n    for i_d,d in enumerate(depths):\n        for i_p,p in enumerate(pattern_thresholds):\n            \n            for i_e,e in enumerate(edge_thresholds):\n                line_arr = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')\n                \n                if (abs(1/ float(line_arr[14])) >=  compression):\n                    index = i_e\n                    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')\n                    #print(line_index)\n                #if (i_e == (len(edge_thresholds) - 1)):\n                #   index = i_e\n                #    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')\n                #    print(edge_thresholds[index])\n                #    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+\n                #         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')\n                        \n                else:\n                    print(edge_thresholds[index])\n                    #line_arr = lines[line_index].split(',')\n                    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+\n                         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')\n                    counter += 1\n                    break\n                    \n\n"

# %%
import os
resultsPath = "../tmp/final_reports/"
dataset = 'adult'
results_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds.csv')
results_file_out = os.path.join(resultsPath, dataset+'/', 'report_thresholds_2.csv')

with open(results_file,'r') as results_f:
    lines = results_f.readlines()
    #results_f.write(lines[0])
    

            
results_f.close()


with open(results_file_out,'w') as results_f_out:
    
    for line in lines:
        #if ('(' in line):
        if('(' in line):
            results_f_out.write(line)

            
results_f_out.close()

'''            
data_test = data_file +'.test'

file_write_train = open(data_train,'w')
file_write_test = open(data_test,'w')
file_read = open(data_all,'r')
lines = file_read.readlines()
for i in range(len(lines)):
    if (i %5 != 0):
        file_write_train.write(lines[i])
    else:
        file_write_test.write(lines[i])
        
        
    
    

file_write_train.close()
file_read.close()
'''
# Out:
# "            \ndata_test = data_file +'.test'\n\nfile_write_train = open(data_train,'w')\nfile_write_test = open(data_test,'w')\nfile_read = open(data_all,'r')\nlines = file_read.readlines()\nfor i in range(len(lines)):\n    if (i %5 != 0):\n        file_write_train.write(lines[i])\n    else:\n        file_write_test.write(lines[i])\n        \n        \n    \n    \n\nfile_write_train.close()\nfile_read.close()\n"

# %%
#reg
import os
import numpy as np
import math

resultsPath = "../tmp/final_reports/"
dataset = 'skin'
results_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds.csv')
results_file_out = os.path.join(resultsPath, dataset+'/', 'report_thresholds_2.csv')

sizes = [25,50,100]
depths = [5,10,15]
pattern_thresholds = [1,2]
edge_thresholds = [1.0,0.975,0.95,0.925,0.9,0.85,0.8,0.7,0.6]
accuracy_drop = 0.02
with open(results_file,'r') as f:
    lines = f.readlines()
f.close() 

with open(results_file_out,'w') as f_out:
    
    f_out.write(lines[0])
    
    
    index = 0
    counter = 0
    line_index = []

    #print('Forest Size, Forest Depth, Patterns Threshold, Edges Threshold, Test Accuracy, Accuracy drop, Patterns Count,Compression, Training Time, Pruning Time,')
    for i_s,s in enumerate(sizes):
        for i_d,d in enumerate(depths):
            for i_p,p in enumerate(pattern_thresholds):
                
                line_arr_ref_nb = lines[index * counter * 3 + 1].split(',')
                line_arr_ref_svm = lines[index * counter * 3 + 2].split(',')
                line_arr_ref_lr = lines[index * counter * 3 + 3].split(',')
                
                for i_e,e in enumerate(edge_thresholds):
                    line_arr_nb = lines[index * counter * 3 +  i_e * 3  + 1].split(',')
                    line_arr_svm = lines[index * counter * 3 +  i_e * 3  + 2].split(',')
                    line_arr_lr = lines[index * counter * 3 +  i_e * 3   + 3].split(',')
                    
                    for i in range(7):
                        f_out.write(line_arr_nb[i] + ',')
                    f_out.write(str(float(line_arr_nb[6]) - float(line_arr_ref_nb[6])) + ',')
                    f_out.write(line_arr_nb[8] + ',')
                    f_out.write(str(float(line_arr_nb[8]) - float(line_arr_ref_nb[8])) + ',')
                    f_out.write(line_arr_nb[10] + ',')
                    f_out.write(str(float(line_arr_nb[10]) - float(line_arr_ref_nb[10])) + ',')
                    for i in range(12,16):
                        f_out.write(line_arr_nb[i] + ',')
                    f_out.write('\n')
                    
                    for i in range(7):
                        f_out.write(line_arr_svm[i] + ',')
                    f_out.write(str(float(line_arr_svm[6]) - float(line_arr_ref_svm[6])) + ',')
                    f_out.write(line_arr_svm[8] + ',')
                    f_out.write(str(float(line_arr_svm[8]) - float(line_arr_ref_svm[8])) + ',')
                    f_out.write(line_arr_svm[10] + ',')
                    f_out.write(str(float(line_arr_svm[10]) - float(line_arr_ref_svm[10])) + ',')
                    for i in range(12,16):
                        f_out.write(line_arr_svm[i] + ',')
                    f_out.write('\n')
                    
                    for i in range(7):
                        f_out.write(line_arr_lr[i] + ',')
                    f_out.write(str(float(line_arr_lr[6]) - float(line_arr_ref_lr[6])) + ',')
                    f_out.write(line_arr_lr[8] + ',')
                    f_out.write(str(float(line_arr_lr[8]) - float(line_arr_ref_lr[8])) + ',')
                    f_out.write(line_arr_lr[10] + ',')
                    f_out.write(str(float(line_arr_lr[10]) - float(line_arr_ref_lr[10])) + ',')
                    for i in range(12,16):
                        f_out.write(line_arr_lr[i] + ',')
                    f_out.write('\n')
                    
                  
                        

                index += 1
                counter = (len(edge_thresholds))

                
                   
                        
                    
'''            
compression = 1.5

index = 0
counter = 0
line_index = []


for i_s,s in enumerate(sizes):
    for i_d,d in enumerate(depths):
        for i_p,p in enumerate(pattern_thresholds):
            
            for i_e,e in enumerate(edge_thresholds):
                line_arr = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                
                if (abs(1/ float(line_arr[14])) >=  compression):
                    index = i_e
                    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                    #print(line_index)
                #if (i_e == (len(edge_thresholds) - 1)):
                #   index = i_e
                #    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                #    print(edge_thresholds[index])
                #    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                #         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                        
                else:
                    print(edge_thresholds[index])
                    #line_arr = lines[line_index].split(',')
                    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                    counter += 1
                    break
                    

'''
# Out:
# "            \ncompression = 1.5\n\nindex = 0\ncounter = 0\nline_index = []\n\n\nfor i_s,s in enumerate(sizes):\n    for i_d,d in enumerate(depths):\n        for i_p,p in enumerate(pattern_thresholds):\n            \n            for i_e,e in enumerate(edge_thresholds):\n                line_arr = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')\n                \n                if (abs(1/ float(line_arr[14])) >=  compression):\n                    index = i_e\n                    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')\n                    #print(line_index)\n                #if (i_e == (len(edge_thresholds) - 1)):\n                #   index = i_e\n                #    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')\n                #    print(edge_thresholds[index])\n                #    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+\n                #         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')\n                        \n                else:\n                    print(edge_thresholds[index])\n                    #line_arr = lines[line_index].split(',')\n                    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+\n                         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')\n                    counter += 1\n                    break\n                    \n\n"

# %%
#classification
import os
import numpy as np
import math

resultsPath = "../tmp/final_reports/"
dataset = 'adult'
results_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds.csv')
results_file_out = os.path.join(resultsPath, dataset+'/', 'report_thresholds_2.csv')

sizes = [25,50,100]
depths = [5,10,15]
pattern_thresholds = [1]
edge_thresholds = [1.0,0.975,0.95,0.925,0.9,0.85,0.8,0.7,0.6]
accuracy_drop = 0.02
with open(results_file,'r') as f:
    lines = f.readlines()
f.close() 

with open(results_file_out,'w') as f_out:
    
    f_out.write(lines[0])
    
    
    index = 0
    counter = 0
    line_index = []

    #print('Forest Size, Forest Depth, Patterns Threshold, Edges Threshold, Test Accuracy, Accuracy drop, Patterns Count,Compression, Training Time, Pruning Time,')
    for i_s,s in enumerate(sizes):
        for i_d,d in enumerate(depths):
            for i_p,p in enumerate(pattern_thresholds):
                
                line_arr_ref_nb = lines[index * counter * 3 + 1].split(',')
                line_arr_ref_svm = lines[index * counter * 3 + 2].split(',')
                line_arr_ref_lr = lines[index * counter * 3 + 3].split(',')
                
                for i_e,e in enumerate(edge_thresholds):
                    line_arr_nb = lines[index * counter * 3 +  i_e * 3  + 1].split(',')
                    line_arr_svm = lines[index * counter * 3 +  i_e * 3  + 2].split(',')
                    line_arr_lr = lines[index * counter * 3 +  i_e * 3   + 3].split(',')
                    
                    for i in range(7):
                        f_out.write(line_arr_nb[i] + ',')
                    f_out.write(str(float(line_arr_nb[6]) - float(line_arr_ref_nb[6])) + ',')
                    f_out.write(line_arr_nb[8] + ',')
                    f_out.write(str(float(line_arr_nb[8]) - float(line_arr_ref_nb[8])) + ',')
                    f_out.write(line_arr_nb[10] + ',')
                    f_out.write(line_arr_nb[11] + ',')
                    f_out.write(str(float(line_arr_nb[11]) - float(line_arr_ref_nb[11])) + ',')
                    for i in range(13,17):
                        f_out.write(line_arr_nb[i] + ',')
                    f_out.write('\n')
                    
                    for i in range(7):
                        f_out.write(line_arr_svm[i] + ',')
                    f_out.write(str(float(line_arr_svm[6]) - float(line_arr_ref_svm[6])) + ',')
                    f_out.write(line_arr_svm[8] + ',')
                    f_out.write(str(float(line_arr_svm[8]) - float(line_arr_ref_svm[8])) + ',')
                    f_out.write(line_arr_svm[10] + ',')
                    f_out.write(line_arr_svm[11] + ',')
                    f_out.write(str(float(line_arr_svm[11]) - float(line_arr_ref_svm[11])) + ',')
                    for i in range(13,17):
                        f_out.write(line_arr_svm[i] + ',')
                    f_out.write('\n')
                    
                    for i in range(7):
                        f_out.write(line_arr_lr[i] + ',')
                    f_out.write(str(float(line_arr_lr[6]) - float(line_arr_ref_lr[6])) + ',')
                    f_out.write(line_arr_lr[8] + ',')
                    f_out.write(str(float(line_arr_lr[8]) - float(line_arr_ref_lr[8])) + ',')
                    f_out.write(line_arr_lr[10] + ',')
                    f_out.write(line_arr_lr[11] + ',')
                    f_out.write(str(float(line_arr_lr[11]) - float(line_arr_ref_lr[11])) + ',')
                    for i in range(13,17):
                        f_out.write(line_arr_lr[i] + ',')
                    f_out.write('\n')
                    
                  
                        

                index += 1
                counter = (len(edge_thresholds))

                
                   
                        
                    
'''            
compression = 1.5

index = 0
counter = 0
line_index = []


for i_s,s in enumerate(sizes):
    for i_d,d in enumerate(depths):
        for i_p,p in enumerate(pattern_thresholds):
            
            for i_e,e in enumerate(edge_thresholds):
                line_arr = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                
                if (abs(1/ float(line_arr[14])) >=  compression):
                    index = i_e
                    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                    #print(line_index)
                #if (i_e == (len(edge_thresholds) - 1)):
                #   index = i_e
                #    line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                #    print(edge_thresholds[index])
                #    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                #         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                        
                else:
                    print(edge_thresholds[index])
                    #line_arr = lines[line_index].split(',')
                    print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                         str(line_index[13])+','+str(1/float(line_index[14]))+','+str((line_index[15]))+','+str(line_index[16])+',')
                    counter += 1
                    break
                    

'''
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_7088/3518721996.py in <module>
#      32             for i_p,p in enumerate(pattern_thresholds):
#      33
# ---> 34                 line_arr_ref_nb = lines[index * counter * 3 + 1].split(',')
#      35                 line_arr_ref_svm = lines[index * counter * 3 + 2].split(',')
#      36                 line_arr_ref_lr = lines[index * counter * 3 + 3].split(',')
#
# IndexError: list index out of range

# %%
import os
import numpy as np
import math
import sys

resultsPath = "../tmp/final_reports/"
dataset = sys.argv[1]
accuracy_drop = float(sys.argv[2])
print(accuracy_drop)
results_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds.csv')

sizes = [25,50,100]
depths = [5,10,15]
pattern_thresholds = [1,2]
edge_thresholds = [1.0,0.975,0.95,0.925,0.9,0.85,0.8,0.7,0.6]

with open(results_file,'r') as f:
    lines = f.readlines()
f.close()  


stats_file = os.path.join(resultsPath, dataset+'/', 'report_thresholds_'+str(accuracy_drop)+'.csv')
with open(stats_file,'w') as f_out:
    f_out.write('Forest Size, Forest Depth, Patterns Threshold, Edges Threshold, Test Accuracy, Accuracy drop, F1 Macro drop, ROC AUC drop, Patterns Count,Compression, Training Time, Pruning Time,\n')
    index = 0
    counter = 0
    line_index = []

    print('Forest Size, Forest Depth, Patterns Threshold, Edges Threshold, Test Accuracy, Accuracy drop, Patterns Count,Compression, Training Time, Pruning Time,')
    for i_s,s in enumerate(sizes):
        for i_d,d in enumerate(depths):
            for i_p,p in enumerate(pattern_thresholds):

                for i_e,e in enumerate(edge_thresholds):
                    line_arr = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                    
                    if (i_e == (len(edge_thresholds) - 1) and abs(float(line_arr[7])) <=  accuracy_drop):
                        index = len(edge_thresholds) - 1
                        line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')
                        print(edge_thresholds[index])
                        #line_arr = lines[line_index].split(',')
                        compression = np.round(1/float(line_index[14]),2)
                        print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                             str(line_index[13])+','+str(compression)+','+str((line_index[15]))+','+str(line_index[16])+',')
                        f_out.write(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+str(line_index[9])+str(line_index[12])+','','str(line_index[13])+','+str(compression)+','+str((line_index[15]))+','+str(line_index[16])+',\n')

                        counter += 1


                    else:
                        
                        if (abs(float(line_arr[7])) <=  accuracy_drop):
                            index = i_e
                            line_index = lines[counter *(len(edge_thresholds)) * 3  + ((i_e + 1) *3)].split(',')

                        else:
                            print(edge_thresholds[index])
                            
                            compression = np.round(1/float(line_index[14]),2)
                            print(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+
                                 str(line_index[13])+','+str(compression)+','+str((line_index[15]))+','+str(line_index[16])+',')
                            f_out.write(str(s)+','+str(d)+','+str(p)+','+str(line_index[3])+','+str(line_index[6])+','+str(line_index[7])+','+str(line_index[9])+str(line_index[12])+
                                 str(line_index[13])+','+str(compression)+','+str((line_index[15]))+','+str(line_index[16])+',\n')

                            counter += 1
                            break
